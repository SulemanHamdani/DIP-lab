# %%
import PIL
from PIL import Image, ImageOps, ImageFilter
import os, sys
import numpy as np

# %%
im = Image.open('turtle.png')

# %%
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1400x1050 at 0x2537752BFD0>

# %%
print (im.format, im.size, im.mode)
# Out:
# PNG (1400, 1050) RGB

# %%
# !python script.py turtle.png

# %%
im_jpg = Image.open('turtle.jpg')

# %%
im_jpg
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1400x1050 at 0x253775597E0>

# %%
print ("Renamed image: ", im.format, im.size, im.mode)
# Out:
# Renamed image:  PNG (1400, 1050) RGB

# %%
im_grayScale = ImageOps.grayscale(im)
im_grayScale
# Out:
# <PIL.Image.Image image mode=L size=1400x1050 at 0x25377559BA0>

# %%
im_smooth = im.filter(ImageFilter.SMOOTH_MORE)
im_smooth
# Out:
# <PIL.Image.Image image mode=RGB size=1400x1050 at 0x253775E2E00>

# %%
im_arr = np.array(im)
im_arr
# Out:
# array([[[223, 164, 254],
#         [223, 164, 254],
#         [223, 164, 254],
#         ...,
#         [223, 164, 254],
#         [222, 160, 254],
#         [229, 181, 254]],
#
#        [[219, 152, 254],
#         [219, 152, 254],
#         [219, 152, 254],
#         ...,
#         [219, 152, 254],
#         [217, 148, 254],
#         [226, 172, 254]],
#
#        [[220, 154, 254],
#         [220, 154, 254],
#         [220, 154, 254],
#         ...,
#         [220, 154, 254],
#         [219, 150, 254],
#         [227, 173, 254]],
#
#        ...,
#
#        [[220, 154, 254],
#         [220, 154, 254],
#         [220, 154, 254],
#         ...,
#         [220, 154, 254],
#         [219, 150, 254],
#         [227, 173, 254]],
#
#        [[219, 150, 254],
#         [219, 150, 254],
#         [219, 150, 254],
#         ...,
#         [219, 150, 254],
#         [218, 146, 254],
#         [226, 170, 254]],
#
#        [[227, 173, 254],
#         [227, 173, 254],
#         [227, 173, 254],
# ...

# %%
im_greyScale_array = np.mean(im_arr, axis = 2)
im_greyScale_array
# Out:
# array([[213.66666667, 213.66666667, 213.66666667, ..., 213.66666667,
#         212.        , 221.33333333],
#        [208.33333333, 208.33333333, 208.33333333, ..., 208.33333333,
#         206.33333333, 217.33333333],
#        [209.33333333, 209.33333333, 209.33333333, ..., 209.33333333,
#         207.66666667, 218.        ],
#        ...,
#        [209.33333333, 209.33333333, 209.33333333, ..., 209.33333333,
#         207.66666667, 218.        ],
#        [207.66666667, 207.66666667, 207.66666667, ..., 207.66666667,
#         206.        , 216.66666667],
#        [218.        , 218.        , 218.        , ..., 218.        ,
#         216.33333333, 225.        ]])

# %%
im_greyScale = Image.fromarray(im_greyScale_array)
im_greyScale.convert('L')
# Out:
# <PIL.Image.Image image mode=L size=1400x1050 at 0x25378CDFB80>
